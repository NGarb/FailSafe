# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_dir = 'D:\\Projects\\FailSafe_500'
import os 
os.chdir(base_dir)
from Utils import heatmap as hmp
os.chdir('.\\9. Clickstream data for online shopping')

# %%
clothing_data_df=pd.read_csv('./data/e-shop data and description/e-shop clothing 2008.csv',sep=';')

# %%
# since we are predicting price, we should remove the 'price 2' variable as this is feature leakage
clothing_data_df = clothing_data_df.drop(['price 2'],axis=1)

# %%
clothing_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165474 entries, 0 to 165473
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     165474 non-null  int64
#  1   month                    165474 non-null  int64
#  2   day                      165474 non-null  int64
#  3   order                    165474 non-null  int64
#  4   country                  165474 non-null  int64
#  5   session ID               165474 non-null  int64
#  6   page 1 (main category)   165474 non-null  int64
#  7   page 2 (clothing model)  165474 non-null  object
#  8   colour                   165474 non-null  int64
#  9   location                 165474 non-null  int64
#  10  model photography        165474 non-null  int64
#  11  price                    165474 non-null  int64
#  12  price 2                  165474 non-null  int64
#  13  page                     165474 non-null  int64
# ...

# %%
set(clothing_data_df.year)
# Out:
# {2008}

# %%
# drop year
clothing_data_df = clothing_data_df.drop(['year'],axis=1)

# %%
len(set(clothing_data_df['page 2 (clothing model)']))
# Out:
# 217

# %%
clothing_data_df['session ID'].value_counts().head() # create feature with len of session visits
# Out:
# 22433    195
# 13846    192
# 22902    185
# 8201     161
# 19623    142
# Name: session ID, dtype: int64

# %%
# no nulls 
# all numeric besides for page 2 - clothing model

# %%
plt.figure(figsize=(5,5)) 
sns.pairplot(clothing_data_df[['order', 'country', 'colour', 'location', 'price']])

# %%
clothing_data_df.hist(figsize=(8,10),bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'order'}>],
#        [<AxesSubplot:title={'center':'country'}>,
#         <AxesSubplot:title={'center':'session ID'}>,
#         <AxesSubplot:title={'center':'page 1 (main category)'}>,
#         <AxesSubplot:title={'center':'colour'}>],
#        [<AxesSubplot:title={'center':'location'}>,
#         <AxesSubplot:title={'center':'model photography'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'price 2'}>],
#        [<AxesSubplot:title={'center':'page'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# %matplotlib inline

corr = clothing_data_df.corr()
plt.figure(figsize=(10, 10))
hmp.corrplot(corr)
# Out:
# ['month', 'day', 'order', 'country', 'session ID', 'page 1 (main category)', 'colour', 'location', 'model photography', 'price', 'price 2', 'page']

# %%
clothing_data_df.location.value_counts()
# Out:
# 1    34532
# 2    33383
# 5    27783
# 4    27377
# 3    21656
# 6    20743
# Name: location, dtype: int64

# %%
clothing_data_df.price.hist(bins = 25)
# Out:
# <AxesSubplot:>

# %%
clothing_data_df.to_csv('./data/e-shop data and description/e-shop clothing 2008.csv',sep=',')
